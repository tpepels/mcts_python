# %%
from games.amazons import *
import random

state = AmazonsGameState()
lieb_max = -1
eval_max = -1
_m = (0.0, 0.4, 0.3, 0.5, 0.2)
for n in range(60):  # Do 100 random actions on the board
    if state.is_terminal():
        break
    actions = state.get_legal_actions()
    state = state.apply_action(*random.sample(actions, 1))
    lieb_max = max(abs(evaluate_lieberum(state, state.player, m=_m, norm=False)), lieb_max)
    # eval_max = max(abs(evaluate(state, state.player, norm=False)), eval_max)
    
moves = state.get_legal_actions()

print(f"Player: {state.player}")
print(f"Reward: {state.get_reward()}, Terminal: {state.is_terminal()}")
print(visualize_amazons(state, True))
print(f"{len(moves)} actions: {state.get_legal_actions()}")
# ------------------------------------------------------------
white_queens = queens_from_board(state.board, True)
black_queens = queens_from_board(state.board, False)
print("---------------")
print(f"Evaluation: {evaluate(state, state.player)} (opponent: {evaluate(state, 3 - state.player)})")
print(f"Evaluate max: {eval_max}")
print("---------------")
print(f"Lieberum Evaluation: {evaluate_lieberum(state, state.player)} (opponent: {evaluate_lieberum(state, 3 - state.player)})")
print(f"Leiberum max: {lieb_max}")
print("---------------")
print(f"White Queens: {white_queens}\nBlack Queens: {black_queens}")
# -------------------------Reachable Squares Test-----------------------------------
for queen in white_queens:
    print(f"White {queen} reachable squares: {count_reachable_squares(state.board, *queen)}")
for queen in black_queens:
    print(f"Black {queen} reachable squares: {count_reachable_squares(state.board, *queen)}")
print()
# -------------------------Kill Save Queens Test-----------------------------------
print(f"White kill/save & imm moves: {kill_save_queens_immediate_moves(black_queens, white_queens, state.board)}")
print(f"Black kill/save & imm moves: {kill_save_queens_immediate_moves(white_queens, black_queens, state.board)}\n")
# -------------------------Mobility Heuristic-----------------------------------
print(f"White mobility: {mobility_heuristic(black_queens, white_queens, state.board)}")
print(f"Black mobility: {mobility_heuristic(white_queens, black_queens, state.board)}\n")
# --------------------------territory_heuristic------------------------------------
print(f"White territory: {territory_heuristic(black_queens, white_queens, state.board)}")
print(f"Black territory: {territory_heuristic(white_queens, black_queens, state.board)}\n")
# Out:
# Player: 1
# Reward: 0, Terminal: False
# W - . W - - - . . -
# . - - - B . . - - -
# - - . . - - - - . B
# . . - - . - - - . B
# . - - - . - . - . -
# - - . - - - - . - -
# . - . - - . - - - -
# W - - - - . . - - -
# - . - - - B - - . .
# - - W - . . . - . .
#
# 5 actions: [(0, 0, 1, 0, 0, 0), (0, 3, 0, 2, 0, 3), (7, 0, 6, 0, 7, 0), (7, 0, 8, 1, 7, 0), (9, 2, 8, 1, 9, 2)]
# ---------------
# Evaluation: -0.5788385707841248 (opponent: 0.5788385707841248)
# Evaluate max: -1
# ---------------
# Lieberum Evaluation: -0.33814805250253505 (opponent: 0.33814805250253505)
# Leiberum max: 49.1
# ---------------
# White Queens: [(0, 0), (0, 3), (7, 0), (9, 2)]
# Black Queens: [(1, 4), (2, 9), (3, 9), (8, 5)]
# White (0, 0) reachable squares: 1
# White (0, 3) reachable squares: 1
# White (7, 0) reachable squares: 2
# White (9, 2) reachable squares: 1
# Black (1, 4) reachable squares: 3
# Black (2, 9) reachable squares: 2
# Black (3, 9) reachable squares: 4
# Black (8, 5) reachable squares: 6
#
# White kill/save & imm moves: (0, -10)
# Black kill/save & imm moves: (0, 10)
#
# White mobility: -22
# Black mobility: 22
#
# White territory: -13
# Black territory: 13
